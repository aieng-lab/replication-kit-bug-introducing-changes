# %%
import os
from dotenv import load_dotenv
from mongoengine import connect, disconnect
import pandas as pd
from pycoshark.mongomodels import People, CodeReview, CodeReviewChangeLog, CodeReviewRevision, CodeReviewComment
import re
import requests
import json

# %%
# Load environment variables from .env file
load_dotenv('.env')

# Retrieve the password from the environment variable
user = os.getenv('DB_USER')
password = os.getenv('DB_PW')
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')

disconnect()

address = f'mongodb://{user}:{password}@{db_host}:{db_port}/{db_name}?authSource=admin'
print(address)
connect(host=address)
# Out:
# mongodb://root:upinndonau@localhost:27017/smartshark?authSource=admin
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', read_preference=Primary())

# %%
author_cache = {}


cnt = 0



def get_comment_data(comment: CodeReviewComment, lines_map, cnt):
    global author_cache

    author = author_cache.get(comment.author_id, People.objects.get(id=comment.author_id))
    author_cache[comment.author_id] = author

    lines = None
    if comment.in_reply_to_id is None:
        lines = lines_map.get(comment.external_id, '')

    return {
        'source': f'p{comment.patch_set_number} {comment.file_path} {comment.line} {cnt}',
        'message': comment.message,
        'lines': lines,
        'author': author.name,
        'date': comment.updated_at
    }



def get_file_chunks(review: CodeReview):
    url = f'https://review.opendev.org/changes/openstack%2Fnova~master~{review.change_id}/comments?enable-context=true&context-padding=5'

    print(url)

    lines_map = {}

    response = requests.get(url).text.split('\n')[1:]

    try:
        data = json.loads(''.join(response))
    except:
        return lines_map

    for path, comments in data.items():
        for comment in comments:
            lines_map[comment.get('id')] = '\n'.join([line.get('context_line') for line in comment.get('context_lines', [])])

    return lines_map

def store_csv(review_external_number):
    global cnt
    global author_cache

    review = CodeReview.objects.get(external_number=review_external_number)

    lines_map = get_file_chunks(review)

    result =  [{
        'source': 'description',
        'message': review.description,
        'lines': None,
        'author': People.objects.get(id=review.author_id).name,
        'date': review.created_at
    }]

    def append_children(parent: CodeReviewComment, cnt):

        children = CodeReviewComment.objects.filter(in_reply_to_id=parent.external_id)
        for child in children:
            cnt += 1
            result.append(get_comment_data(child, lines_map, cnt))
            append_children(child, cnt)


    review_comments_parent = CodeReviewComment.objects.filter(code_review_id=review.id, in_reply_to_id=None).order_by('patch_set_number')

    for parent in review_comments_parent:
        cnt = 0
        result.append(get_comment_data(parent, lines_map, cnt))
        append_children(parent, cnt)


    excluded_names_regex = f'(:?{"|".join(["trivial rebase", "Intel PCI CI", "VMware NSX CI", "SmokeStack CI", "Microsoft Hyper-V CI", "Citrix XenServer CI", "IBM PowerKVM CI", "DB Datasets CI", "Jenkins"])})'.lower()
    excluded_names_regex = re.compile(excluded_names_regex, re.IGNORECASE)
    excluded_authors = People.objects.filter(name=excluded_names_regex)

    review_logs = CodeReviewChangeLog.objects.filter(code_review_id=review.id, author_id__nin=[author.id for author in excluded_authors]).order_by('created_at')
    revision_cache = {}


    for log in review_logs:
        revision = revision_cache.get(log.revision_id, CodeReviewRevision.objects.get(id=log.revision_id))
        revision_cache[log.revision_id] = revision

        if (re.findall(f'uploaded patch set {revision.revision_number}', log.message, flags=re.IGNORECASE) 
            or re.findall(f'^patch set {revision.revision_number}: \(\d+ inline comments?\)\n+$', log.message, flags=re.IGNORECASE)):
            continue

        author = author_cache.get(log.author_id, People.objects.get(id=log.author_id))
        author_cache[log.author_id] = author

        result.append({
            'source': f'p{revision.revision_number} log {author.name}',
            'message': log.message,
            'lines': None,
            'author': author.name,
            'date': log.created_at
        })


    df = pd.DataFrame(result)

    df.to_csv(f'review_comments/review_comments_{review_external_number}.csv', index=False)
    print(f'review_comments_{review_external_number}.csv saved!')

# %%
reviews = [1324, 1934, 10903, 14805, 14806, 17839, 17946, 18864, 19457, 19679, 22897, 24363, 26113, 28774, 28880, 29062, 30201, 31593, 34464, 40426, 40467, 42389, 44239, 53069, 59034, 59560, 63178, 63612, 64289, 65042, 67338, 70215, 70747, 74537, 93754, 94294, 94811, 102324, 107009, 107602, 109489, 113545, 113741, 113772, 119396, 119446, 120675, 123682, 124714, 129235, 132231, 136717, 140337, 142282, 144792, 145007, 150293, 151664, 155678, 155853, 164940, 175551]


for review in reviews:
    store_csv(review)
# Out:
# https://review.opendev.org/changes/openstack%2Fnova~master~I034404892018e99987f80789d7f7e406ff31658c/comments?enable-context=true&context-padding=5
# review_comments_1324.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I8877fad3d41ae055c15b1adff99e535c34e9ce92/comments?enable-context=true&context-padding=5
# review_comments_1934.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I51645687249c75e7776a684f19529a1e78f33a41/comments?enable-context=true&context-padding=5
# review_comments_10903.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I0d4a7dc5836d39e405824528de214f23b214849f/comments?enable-context=true&context-padding=5
# review_comments_14805.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ieaa33efd50bb84f1b475c437b26af1302fdfd19f/comments?enable-context=true&context-padding=5
# review_comments_14806.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ia89b613d7d934a0072f262add039fe14ef236334/comments?enable-context=true&context-padding=5
# review_comments_17839.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I30489234b8329f576cf2cbb0ef390670dbee5b95/comments?enable-context=true&context-padding=5
# review_comments_17946.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~If1334256680e7075598f00ce153cf6f021cc720f/comments?enable-context=true&context-padding=5
# review_comments_18864.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I1f560367cb895602b359a51a9da9cb044013e936/comments?enable-context=true&context-padding=5
# review_comments_19457.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I1b39a7be5bd21d5b3060f11a74b9eaf79b107210/comments?enable-context=true&context-padding=5
# review_comments_19679.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I85bc0f6e9cda10aa85328199d107a3ff6e240b96/comments?enable-context=true&context-padding=5
# review_comments_22897.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I05a623849680c5d0bb530fba4c4e6051d3b000aa/comments?enable-context=true&context-padding=5
# review_comments_24363.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I9241137ad794cdf7f452ed84e9445f0e11fdd44e/comments?enable-context=true&context-padding=5
# review_comments_26113.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Iedd039af54d2233d1afbc7fe2d21d1b3594c47b1/comments?enable-context=true&context-padding=5
# review_comments_28774.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I615af9826ef61fd63d4cd8017908f943969bf177/comments?enable-context=true&context-padding=5
# review_comments_28880.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I92358bcda157c95290b31e3b7997e3432a65b404/comments?enable-context=true&context-padding=5
# review_comments_29062.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I9bde984d2393bd73a73eae6065defb2ed7c01492/comments?enable-context=true&context-padding=5
# review_comments_30201.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Iaba099225a9b3b0390cae4c5fbd82d7e6c11f0e0/comments?enable-context=true&context-padding=5
# review_comments_31593.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I7046ce55a0a294293c1b1a5fb0f092aeb891ee01/comments?enable-context=true&context-padding=5
# review_comments_34464.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I0989ed4f248cd1126d4703ad6498cfd66685ae31/comments?enable-context=true&context-padding=5
# review_comments_40426.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I871af4018f99ddfcc8408708bdaaf480088ac477/comments?enable-context=true&context-padding=5
# review_comments_40467.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I4f9e3fd0b7bb443406645c1d98e673a4d3624b58/comments?enable-context=true&context-padding=5
# review_comments_42389.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I570ba5096289538d2364b44f2cdc2ac7ac0a527b/comments?enable-context=true&context-padding=5
# review_comments_44239.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Idd1862c7f212dc253b6273b07b020c86a94e658e/comments?enable-context=true&context-padding=5
# review_comments_53069.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I441cf8f2df0b92a9cc4096e77a90c37a06270eb5/comments?enable-context=true&context-padding=5
# review_comments_59034.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I4b17c8382619e4f73b83c026bf68549ac67a68a2/comments?enable-context=true&context-padding=5
# review_comments_59560.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I357daa5ae627e8959b77bd0cb00e152810f9c0eb/comments?enable-context=true&context-padding=5
# review_comments_63178.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ia5cc55aca5517359523ae71f4110b5f02a830b4d/comments?enable-context=true&context-padding=5
# review_comments_63612.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I27e5ed5c51926cfeb6747980df02a396f566dd77/comments?enable-context=true&context-padding=5
# review_comments_64289.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I8a88824bbb41807fad849ad15af4411d3a3dca6e/comments?enable-context=true&context-padding=5
# review_comments_65042.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ia191148cf7510ffdb0fbd4186fa34bb4c5ab1b0f/comments?enable-context=true&context-padding=5
# review_comments_67338.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ie070c17495f7a4cc6210d256a3170ac9c06e198f/comments?enable-context=true&context-padding=5
# review_comments_70215.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ic63a3afb77362f0797c546a9505fa4bd7a9b986e/comments?enable-context=true&context-padding=5
# review_comments_70747.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ia980f65384af2818f46d2e91df46f131b2ce3a77/comments?enable-context=true&context-padding=5
# review_comments_74537.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ic9c60071480abc5fced04dab5fc79ea44db1e10d/comments?enable-context=true&context-padding=5
# review_comments_93754.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I92cd6b16fbd93b377fe47b15d22efbbf68d02513/comments?enable-context=true&context-padding=5
# review_comments_94294.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I7c9d677e7b589b525e2c6ebc43ef81a64a57511d/comments?enable-context=true&context-padding=5
# review_comments_94811.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~If863cf813dddc1e4554fb87b945c68b75b25f9a2/comments?enable-context=true&context-padding=5
# review_comments_102324.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I1bec4f009285f7991eaaa8155329366a4eba5e1f/comments?enable-context=true&context-padding=5
# review_comments_107009.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I7402cfc28d4ee7989c7eb054556df57918bbaeee/comments?enable-context=true&context-padding=5
# review_comments_107602.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Icb19148660bca542a8120ecab064551d67ac28af/comments?enable-context=true&context-padding=5
# review_comments_109489.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I9aee622cca4578149201f02d02231a7bd0cbe912/comments?enable-context=true&context-padding=5
# review_comments_113545.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Id22eb46ed3b4bd8fb48189a40f9df9bb114cd3d4/comments?enable-context=true&context-padding=5
# review_comments_113741.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Icf5875b68ecde85c044efb1e2b05416de8b0c9db/comments?enable-context=true&context-padding=5
# review_comments_113772.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I2d46b926f1c895aba412d84b4ee059fda3df9011/comments?enable-context=true&context-padding=5
# review_comments_119396.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ib82ea58e85f6ccab6008f2d19a31d0e890136ca7/comments?enable-context=true&context-padding=5
# review_comments_119446.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I81591b18d1045a4451ce009b091b22875eb04890/comments?enable-context=true&context-padding=5
# review_comments_120675.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ided6c71b68a654476512016ddf886e895d75e571/comments?enable-context=true&context-padding=5
# review_comments_123682.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I0b8e6319a4cc39876b1e396ef705f0fc5def1e44/comments?enable-context=true&context-padding=5
# review_comments_124714.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Id5de0e6843c1035235598a4d72a00b7555187fb4/comments?enable-context=true&context-padding=5
# review_comments_129235.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ife979bca1699fc06e5a40264ba3e8173b9e0143b/comments?enable-context=true&context-padding=5
# review_comments_132231.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I7825d1a1ed44f0393eec0bfcc3a03ec0905be482/comments?enable-context=true&context-padding=5
# review_comments_136717.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ie87545310f3c1261bbcb2a010b2d2a1d9dc45ca0/comments?enable-context=true&context-padding=5
# review_comments_140337.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I3ce858062a3d28b9d4b8fe4bd8f2b9a826318b82/comments?enable-context=true&context-padding=5
# review_comments_142282.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ibc745e9a63bc3d5d68217020b3d591f71c3f8a96/comments?enable-context=true&context-padding=5
# review_comments_144792.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ibcb108c2e0f84a84c599d2e7762a11efc7659395/comments?enable-context=true&context-padding=5
# review_comments_145007.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I0ea6d30ec3dd93cc0133c2bfb64da48cc8eb463a/comments?enable-context=true&context-padding=5
# review_comments_150293.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I6fcbfa31a79c7808c861bb3a84b56bd096882004/comments?enable-context=true&context-padding=5
# review_comments_151664.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~Ia53afcbd0294f9e864339230338b505bff2e7ca1/comments?enable-context=true&context-padding=5
# review_comments_155678.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I850e51e730c82906f68fddb14fb0004d7091eb91/comments?enable-context=true&context-padding=5
# review_comments_155853.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I29c89e9a17f9a170dbe61e4fe14672d481c4fb78/comments?enable-context=true&context-padding=5
# review_comments_164940.csv saved!
# https://review.opendev.org/changes/openstack%2Fnova~master~I972e1d79e570d57baac613e56570b49e1b1da28d/comments?enable-context=true&context-padding=5
# review_comments_175551.csv saved!
