# %%
import os
from dotenv import load_dotenv
from mongoengine import connect, disconnect
import pandas as pd
from pycoshark.mongomodels import Issue, Project, Commit, PullRequestCommit
import re

# %%
# Load environment variables from .env file
load_dotenv('.env')

# Retrieve the password from the environment variable
user = os.getenv('DB_USER')
password = os.getenv('DB_PW')
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')

disconnect()

connect(host=f'mongodb://{user}:{password}@{db_host}:{db_port}/{db_name}?authSource=admin')
# Out:
# MongoClient(host=['37.114.42.132:9001'], document_class=dict, tz_aware=False, connect=True, authsource='admin', read_preference=Primary())

# %%
project = "elasticsearch"

Project.objects.get(name=project)
# Out:
# <Project: Project object>

# %%
issue_bfc = [(row['issue_id'], row['revision_hash']) for (index, row) in pd.read_csv(f'{project}.csv', sep='\t').iterrows()]

# %%
result = {}

def flatten(xss):
    return [x for xs in xss for x in xs]

def get_data(commits: [Commit]):
    return [{
        "revision_hash": commit.revision_hash,
        "author_date": commit.author_date,
        "is_merge": len(commit.parents) > 1,
        "is_rebase": any([parent.author_date > commit.author_date for parent in Commit.objects(revision_hash__in=commit.parents)]),
        "is_review_commit": PullRequestCommit.objects(commit_sha=commit.revision_hash).count()
    } for commit in commits] if len(commits) else [{"revision_hash": None, "author_date": None, "is_merge": None, "is_rebase": None, "is_review_commit": None}]

for issue_id, rev_hash in issue_bfc:    

    if not rev_hash:
        print(issue_id, "No root found")
        continue

    regex = re.compile(rev_hash)
    root = Commit.objects(revision_hash=regex).first()


    parents = Commit.objects(revision_hash__in=root.parents)
    grandparents = Commit.objects(revision_hash__in=flatten([parent.parents for parent in parents]))
    children =Commit.objects(parents=root.revision_hash)
    children_parents = Commit.objects(revision_hash__in=flatten([child.parents for child in children]))

    result[f'{issue_id}'] = {
        'root': rev_hash,
        'true_root': get_data([root])[0],
        'parents': get_data(parents),
        'grandparents': get_data(grandparents),
        'children': get_data(children),
        'children_parents': get_data(children_parents)
    }

result = pd.DataFrame(result).T

# %%
result = result.explode('parents')
result = result.explode('grandparents')
result = result.explode('children')
result = result.explode('children_parents')

# %%
def make_list(prefix):
    return [f'{prefix}_{col}' for col in ['revision_hash', 'author_date', 'is_merge', 'is_rebase', 'is_review_commit']]

result[make_list('true_root')] = result['true_root'].apply(pd.Series)
result.drop('true_root', axis=1, inplace=True)

result[make_list('parents')] = result['parents'].apply(pd.Series)
result.drop('parents', axis=1, inplace=True)

result[make_list('grandparents')] = result['grandparents'].apply(pd.Series)
result.drop('grandparents', axis=1, inplace=True)

result[make_list('children')] = result['children'].apply(pd.Series)
result.drop('children', axis=1, inplace=True)

result[make_list('children_parents')] = result['children_parents'].apply(pd.Series)
result.drop('children_parents', axis=1, inplace=True)

# %%
result.head()
# Out:
#                                                           root  \
# Elastic Search 1134   10660d390d760cde78fb115107c04e1cf104a4da
# Elastic Search 1154   7a38e384c9ff783f17e9db92a730bdf654dbda6b
# Elastic Search 1162   e5b041c8efd408fdc71fd2f2c84439e5a4985244
# Elastic Search 12193  e88535a67e9594f3135465b5021ba9b502fef950
# Elastic Search 1380   16a046f686c26309ee0041df8987a4d2ffedd956
#
#                                        true_root_revision_hash  \
# Elastic Search 1134   10660d390d760cde78fb115107c04e1cf104a4da
# Elastic Search 1154   7a38e384c9ff783f17e9db92a730bdf654dbda6b
# Elastic Search 1162   e5b041c8efd408fdc71fd2f2c84439e5a4985244
# Elastic Search 12193  e88535a67e9594f3135465b5021ba9b502fef950
# Elastic Search 1380   16a046f686c26309ee0041df8987a4d2ffedd956
#
#                      true_root_author_date  true_root_is_merge  \
# Elastic Search 1134    2011-07-18 19:15:22               False
# Elastic Search 1154    2010-03-04 23:48:56               False
# Elastic Search 1162    2010-08-26 21:41:55               False
# Elastic Search 12193   2015-06-13 09:28:05               False
# Elastic Search 1380    2011-04-07 11:30:12               False
#
#                       true_root_is_rebase  true_root_is_review_commit  \
# Elastic Search 1134                 False                           0
# Elastic Search 1154                 False                           0
# Elastic Search 1162                 False                           0
# Elastic Search 12193                False                           0
# Elastic Search 1380                 False                           0
#
#                                          parents_revision_hash  \
# Elastic Search 1134   04086985f415896c245a3ea2fc853042f022822c
# Elastic Search 1154   7bf0f1ffca589df6e626d61182689bde005ce649
# Elastic Search 1162   19ddee5ec9544cf93a1db48e58b7b4b7d841c370
# Elastic Search 12193  364cbbd28232a2a111158de6993692875f7fe1d8
# Elastic Search 1380   7decb701d9c3cbdeafdd1abe1fd3bd2c3d995d8c
#
#                      parents_author_date  parents_is_merge  parents_is_rebase  \
# Elastic Search 1134  2011-07-18 18:29:29             False              False
# Elastic Search 1154  2010-03-04 23:39:04             False              False
# Elastic Search 1162  2010-08-26 15:12:51             False              False
# Elastic Search 12193 2015-06-13 08:34:36             False              False
# Elastic Search 1380  2011-04-07 11:16:21             False              False
#
#                       ...                    children_revision_hash  \
# Elastic Search 1134   ...  d905e6220970898c44b43d56f936e56b53fa3f4f
# Elastic Search 1154   ...  45489ed1af13c6090486c9357e8745c4929d4a83
# Elastic Search 1162   ...  e85c47db744334bf049a04656e7d8b19ac312af0
# Elastic Search 12193  ...  58ccb39deea9afb136d8ad9ce6defc7c67b52cad
# Elastic Search 1380   ...  7fcf82af807608a3e05a388ae16e713b55982cd0
#
#                      children_author_date children_is_merge  \
# Elastic Search 1134   2011-07-18 19:56:28             False
# Elastic Search 1154   2010-03-04 23:50:40             False
# Elastic Search 1162   2010-08-27 10:52:58             False
# Elastic Search 12193  2015-06-13 18:29:18             False
# Elastic Search 1380   2011-04-07 11:44:34             False
#
#                       children_is_rebase  children_is_review_commit  \
# Elastic Search 1134                False                          0
# Elastic Search 1154                False                          0
# Elastic Search 1162                False                          0
# Elastic Search 12193               False                          0
# Elastic Search 1380                False                          0
#
#                                 children_parents_revision_hash  \
# Elastic Search 1134   10660d390d760cde78fb115107c04e1cf104a4da
# Elastic Search 1154   7a38e384c9ff783f17e9db92a730bdf654dbda6b
# Elastic Search 1162   e5b041c8efd408fdc71fd2f2c84439e5a4985244
# Elastic Search 12193  e88535a67e9594f3135465b5021ba9b502fef950
# Elastic Search 1380   16a046f686c26309ee0041df8987a4d2ffedd956
#
#                      children_parents_author_date children_parents_is_merge  \
# Elastic Search 1134           2011-07-18 19:15:22                     False
# Elastic Search 1154           2010-03-04 23:48:56                     False
# Elastic Search 1162           2010-08-26 21:41:55                     False
# Elastic Search 12193          2015-06-13 09:28:05                     False
# Elastic Search 1380           2011-04-07 11:30:12                     False
#
#                       children_parents_is_rebase  \
# Elastic Search 1134                        False
# Elastic Search 1154                        False
# Elastic Search 1162                        False
# Elastic Search 12193                       False
# Elastic Search 1380                        False
#
#                       children_parents_is_review_commit
# Elastic Search 1134                                   0
# Elastic Search 1154                                   0
# Elastic Search 1162                                   0
# Elastic Search 12193                                  0
# Elastic Search 1380                                   0
#
# [5 rows x 26 columns]

# %%
u = set()

prefix = ""

def my_function(row):
    if row[f'{prefix}_revision_hash'] in u:
        row[f'{prefix}_revision_hash'] = None
        row[f'{prefix}_author_date'] = None
        row[f'{prefix}_is_merge'] = None
        row[f'{prefix}_is_rebase'] = None
        row[f'{prefix}_is_review_commit'] = None
    else:
        u.add(row[f'{prefix}_revision_hash'])

    return row

for prefix in ['true_root', 'parents', 'grandparents', 'children', 'children_parents']:
    u = set()
    result = result.apply(my_function, axis=1)

# %%
result
# Out:
#                                                           root  \
# Elastic Search 1134   10660d390d760cde78fb115107c04e1cf104a4da
# Elastic Search 1154   7a38e384c9ff783f17e9db92a730bdf654dbda6b
# Elastic Search 1162   e5b041c8efd408fdc71fd2f2c84439e5a4985244
# Elastic Search 12193  e88535a67e9594f3135465b5021ba9b502fef950
# Elastic Search 1380   16a046f686c26309ee0041df8987a4d2ffedd956
# Elastic Search 14782  a75adaaaaaa632c036464da8fa24770796f77852
# Elastic Search 14782  a75adaaaaaa632c036464da8fa24770796f77852
# Elastic Search 15858  4088236cf75b793c7a2a80f5f7be5b326b607378
# Elastic Search 16246  7caee2fa4d918d4c6978bcf986a158d03bf7db2a
# Elastic Search 1626   1f30681a84fcafe9cf6e6b8a2801ea1791b9edc0
# Elastic Search 16790  093791e82dfe7c3e16ddb1f199fede2cf86b6797
# Elastic Search 16790  093791e82dfe7c3e16ddb1f199fede2cf86b6797
# Elastic Search 16790  093791e82dfe7c3e16ddb1f199fede2cf86b6797
# Elastic Search 16790  093791e82dfe7c3e16ddb1f199fede2cf86b6797
# Elastic Search 1725   3d310406b71973e82f94f60b8dab0c90729a579a
# Elastic Search 1814   b31b0e979c616251ed75b18a87193bd76b75eff3
# Elastic Search 1948   8587f1611912c6633b72909939e91d226575dd90
# Elastic Search 1960   103221e58a85dc5d133cc70af898102735c4375f
# Elastic Search 200    2ea7423f3ac68578a81d92f50b6484cf1db2203d
# Elastic Search 2566   aa68667d636d61b0cc67810e1e2489d1246e9af6
# Elastic Search 2608   8285ffe22175bf4592e79bb881a6451741ccdac8
# Elastic Search 2991   bc20f068c9c62b69260f3b24adaaf9fb3ff3d371
# Elastic Search 3242   4f5e62e9882b36271280ad4e47e61aba2d7669f1
# Elastic Search 3267   567cf6b5c3bbc4486b0472c8abe588ab6215637c
# Elastic Search 3560   a235a5594338789a448742fce19549206dd5b30c
# Elastic Search 4581   22722840d4331a83fcfdd8edea22d372feba16ab
# Elastic Search 4814   3f1472505723866794d875c00bde575d988e120d
# Elastic Search 5021   07443089ce761cdfcf9206ad179381db7249d01a
# Elastic Search 5048   e7e1667a26de5472e3419c586682b92c37c6e7d3
# Elastic Search 5165   459d59a04ad4eb1671bac50a6faf3a7ad372d0e4
# Elastic Search 5948   8561f897a984807958a543e378ab01349935a739
# Elastic Search 7623   ef85412f98e97ff5471013eab59fd8cb3046c17a
# Elastic Search 764    7180636df6dfe6b18bf738ee2285549ea95a8cb9
# Elastic Search 7686   90a339ad5e4a61e750d0342be6326de46f45bedc
# Elastic Search 8125   c55341bf515fec6d4135cee8a6e9a7a9764da17f
# Elastic Search 8438   976448e3395609276446e2b8dbeddb046823aa2e
# Elastic Search 8507   91c4824a0f768f2d3e3651958656384d0735a85e
# Elastic Search 8526   fc51ebfce8a87252d868d1f160ae740972b8e48a
# Elastic Search 8580   8865e60e936b57feb1a31d23b29ba0b212492766
# Elastic Search 864    03ee0a942df39c01e5e4f4ecb392a746e3d979af
# Elastic Search 8893   4f131dfffbdadf5c5f9c9b7a03f9660233e04f72
# Elastic Search 9317   bb49554c33b310e0e615c12befe8846a7d27c951
#
#                                        true_root_revision_hash  \
# Elastic Search 1134   10660d390d760cde78fb115107c04e1cf104a4da
# Elastic Search 1154   7a38e384c9ff783f17e9db92a730bdf654dbda6b
# Elastic Search 1162   e5b041c8efd408fdc71fd2f2c84439e5a4985244
# Elastic Search 12193  e88535a67e9594f3135465b5021ba9b502fef950
# Elastic Search 1380   16a046f686c26309ee0041df8987a4d2ffedd956
# Elastic Search 14782  a75adaaaaaa632c036464da8fa24770796f77852
# Elastic Search 14782                                      None
# Elastic Search 15858  4088236cf75b793c7a2a80f5f7be5b326b607378
# Elastic Search 16246  7caee2fa4d918d4c6978bcf986a158d03bf7db2a
# Elastic Search 1626   1f30681a84fcafe9cf6e6b8a2801ea1791b9edc0
# Elastic Search 16790  093791e82dfe7c3e16ddb1f199fede2cf86b6797
# Elastic Search 16790                                      None
# Elastic Search 16790                                      None
# Elastic Search 16790                                      None
# Elastic Search 1725   3d310406b71973e82f94f60b8dab0c90729a579a
# Elastic Search 1814   b31b0e979c616251ed75b18a87193bd76b75eff3
# Elastic Search 1948   8587f1611912c6633b72909939e91d226575dd90
# Elastic Search 1960   103221e58a85dc5d133cc70af898102735c4375f
# Elastic Search 200    2ea7423f3ac68578a81d92f50b6484cf1db2203d
# Elastic Search 2566   aa68667d636d61b0cc67810e1e2489d1246e9af6
# Elastic Search 2608   8285ffe22175bf4592e79bb881a6451741ccdac8
# Elastic Search 2991   bc20f068c9c62b69260f3b24adaaf9fb3ff3d371
# Elastic Search 3242   4f5e62e9882b36271280ad4e47e61aba2d7669f1
# Elastic Search 3267   567cf6b5c3bbc4486b0472c8abe588ab6215637c
# Elastic Search 3560   a235a5594338789a448742fce19549206dd5b30c
# Elastic Search 4581   22722840d4331a83fcfdd8edea22d372feba16ab
# Elastic Search 4814   3f1472505723866794d875c00bde575d988e120d
# Elastic Search 5021   07443089ce761cdfcf9206ad179381db7249d01a
# Elastic Search 5048   e7e1667a26de5472e3419c586682b92c37c6e7d3
# Elastic Search 5165   459d59a04ad4eb1671bac50a6faf3a7ad372d0e4
# Elastic Search 5948   8561f897a984807958a543e378ab01349935a739
# Elastic Search 7623   ef85412f98e97ff5471013eab59fd8cb3046c17a
# Elastic Search 764    7180636df6dfe6b18bf738ee2285549ea95a8cb9
# Elastic Search 7686   90a339ad5e4a61e750d0342be6326de46f45bedc
# Elastic Search 8125   c55341bf515fec6d4135cee8a6e9a7a9764da17f
# Elastic Search 8438   976448e3395609276446e2b8dbeddb046823aa2e
# Elastic Search 8507   91c4824a0f768f2d3e3651958656384d0735a85e
# Elastic Search 8526   fc51ebfce8a87252d868d1f160ae740972b8e48a
# Elastic Search 8580   8865e60e936b57feb1a31d23b29ba0b212492766
# Elastic Search 864    03ee0a942df39c01e5e4f4ecb392a746e3d979af
# Elastic Search 8893   4f131dfffbdadf5c5f9c9b7a03f9660233e04f72
# Elastic Search 9317   bb49554c33b310e0e615c12befe8846a7d27c951
#
#                      true_root_author_date true_root_is_merge  \
# Elastic Search 1134    2011-07-18 19:15:22              False
# Elastic Search 1154    2010-03-04 23:48:56              False
# Elastic Search 1162    2010-08-26 21:41:55              False
# Elastic Search 12193   2015-06-13 09:28:05              False
# Elastic Search 1380    2011-04-07 11:30:12              False
# Elastic Search 14782   2015-08-17 13:52:36              False
# Elastic Search 14782                   NaT               None
# Elastic Search 15858   2011-09-27 10:47:59              False
# Elastic Search 16246   2015-11-25 17:54:48              False
# Elastic Search 1626    2011-08-27 14:40:00              False
# Elastic Search 16790   2015-09-22 04:57:51              False
# Elastic Search 16790                   NaT               None
# Elastic Search 16790                   NaT               None
# Elastic Search 16790                   NaT               None
# Elastic Search 1725    2010-05-13 18:07:30              False
# Elastic Search 1814    2010-09-09 12:47:55              False
# Elastic Search 1948    2011-02-01 20:16:09              False
# Elastic Search 1960    2010-11-29 00:55:23              False
# Elastic Search 200     2010-03-31 21:20:45              False
# Elastic Search 2566    2010-09-21 15:32:34              False
# Elastic Search 2608    2010-11-28 00:23:38              False
# Elastic Search 2991    2013-01-30 10:49:20              False
# Elastic Search 3242    2012-09-21 11:36:19              False
# Elastic Search 3267    2011-07-11 18:49:33              False
# Elastic Search 3560    2013-07-30 15:06:55              False
# Elastic Search 4581    2012-11-26 08:04:26              False
# Elastic Search 4814    2014-01-17 14:13:51              False
# Elastic Search 5021    2013-12-18 14:44:57              False
# Elastic Search 5048    2013-12-18 15:39:15              False
# Elastic Search 5165    2013-08-16 08:57:17              False
# Elastic Search 5948    2014-01-15 17:22:36              False
# Elastic Search 7623    2010-03-12 14:30:30              False
# Elastic Search 764     2010-10-03 12:31:36              False
# Elastic Search 7686    2011-04-04 21:17:07              False
# Elastic Search 8125    2014-08-28 18:58:34              False
# Elastic Search 8438    2014-07-30 17:06:52              False
# Elastic Search 8507    2014-07-14 11:22:58              False
# Elastic Search 8526    2013-05-27 21:25:24              False
# Elastic Search 8580    2014-07-14 08:42:15              False
# Elastic Search 864     2010-03-02 22:50:53              False
# Elastic Search 8893    2014-07-10 16:01:03              False
# Elastic Search 9317    2014-11-05 22:12:54              False
#
#                      true_root_is_rebase  true_root_is_review_commit  \
# Elastic Search 1134                False                         0.0
# Elastic Search 1154                False                         0.0
# Elastic Search 1162                False                         0.0
# Elastic Search 12193               False                         0.0
# Elastic Search 1380                False                         0.0
# Elastic Search 14782               False                         0.0
# Elastic Search 14782                None                         NaN
# Elastic Search 15858               False                         1.0
# Elastic Search 16246               False                         2.0
# Elastic Search 1626                 True                         0.0
# Elastic Search 16790               False                         1.0
# Elastic Search 16790                None                         NaN
# Elastic Search 16790                None                         NaN
# Elastic Search 16790                None                         NaN
# Elastic Search 1725                False                         0.0
# Elastic Search 1814                False                         0.0
# Elastic Search 1948                False                         1.0
# Elastic Search 1960                False                         0.0
# Elastic Search 200                 False                         0.0
# Elastic Search 2566                False                         0.0
# Elastic Search 2608                False                         0.0
# Elastic Search 2991                False                         0.0
# Elastic Search 3242                False                         1.0
# Elastic Search 3267                False                         0.0
# Elastic Search 3560                False                         0.0
# Elastic Search 4581                False                         0.0
# Elastic Search 4814                 True                         0.0
# Elastic Search 5021                False                         0.0
# Elastic Search 5048                 True                         0.0
# Elastic Search 5165                False                         0.0
# Elastic Search 5948                False                         0.0
# Elastic Search 7623                False                         0.0
# Elastic Search 764                 False                         0.0
# Elastic Search 7686                False                         0.0
# Elastic Search 8125                False                         0.0
# Elastic Search 8438                False                         0.0
# Elastic Search 8507                False                         0.0
# Elastic Search 8526                False                         0.0
# Elastic Search 8580                False                         1.0
# Elastic Search 864                 False                         0.0
# Elastic Search 8893                False                         1.0
# Elastic Search 9317                False                         0.0
#
#                                          parents_revision_hash  \
# Elastic Search 1134   04086985f415896c245a3ea2fc853042f022822c
# Elastic Search 1154   7bf0f1ffca589df6e626d61182689bde005ce649
# Elastic Search 1162   19ddee5ec9544cf93a1db48e58b7b4b7d841c370
# Elastic Search 12193  364cbbd28232a2a111158de6993692875f7fe1d8
# Elastic Search 1380   7decb701d9c3cbdeafdd1abe1fd3bd2c3d995d8c
# Elastic Search 14782  d1c93fb57354d5e0b176ac4501db1167f0af4549
# Elastic Search 14782                                      None
# Elastic Search 15858  f63727e3c6c16b995099ff5a9c1f29635a23c7ed
# Elastic Search 16246  c3f97e7642f6f5208656b35629af08cccaaaeb22
# Elastic Search 1626   ba352e0dc6f3078344a3bf1bec2c1e4233357848
# Elastic Search 16790  8aa6aec34433e7d5f74b25fe59bb84ce1a6a9d5b
# Elastic Search 16790                                      None
# Elastic Search 16790                                      None
# Elastic Search 16790                                      None
# Elastic Search 1725   6cd3fc92edf0e02fa922e59c55e271a9fde9df02
# Elastic Search 1814   31362e4c601ff49b8dd37ef04283cce6fa1f130c
# Elastic Search 1948   237e936884f326585c141af483814eb533dc9ee9
# Elastic Search 1960   84f97e96a5e415a5af6ce452e3797f17242b994a
# Elastic Search 200    def8caf7db2cdd7bfb35ef19ec7eb384948806a5
# Elastic Search 2566   32acd88b2e5018e746b49bbbef4b1a3fc7049619
# Elastic Search 2608   cfa8c9aa7955655374afab61e0049ef3e08182d2
# Elastic Search 2991   e074e00f7602aee80a34897b96636cd6386e5216
# Elastic Search 3242   8080fdc509d22750035573f5837c50968844475d
# Elastic Search 3267   6be337e184c221e5c0fd5d17a39056dff3c38703
# Elastic Search 3560   33d8571d1e7dc01fc287dec1ffb7f428b5116eb0
# Elastic Search 4581   f1297eec815b6c4d1ff2c91dc34104d4e9d9381c
# Elastic Search 4814   1fba68a6349404d0c0a6841a52d6982c21d3b58a
# Elastic Search 5021   17e7d01753b023b5c2d3ad06268655c55ed70103
# Elastic Search 5048   bb4d3f55c0865e9fd49fa2cb5ba03eba360b6ba8
# Elastic Search 5165   f0914d13af4e4c0a2c363e9e64c930e815d8aaba
# Elastic Search 5948   f88f5e2fb7a5c04aff1536e96967cbba7c74b423
# Elastic Search 7623   471801b484bc4374448a42f7a25e2a1554cb27a1
# Elastic Search 764    80b8898542224cca61cf3b1f61afa34f4ac4f128
# Elastic Search 7686   8d1e9dbd3cd9007356abaaf363a9b04019b9d2a8
# Elastic Search 8125   4c690fae472eaaba933bb975b6a1c99ceded965c
# Elastic Search 8438   0005eab665e3130704efb1a54099ab78d58ec06a
# Elastic Search 8507   fcf4d5a38de733eade12c4af4388aa946bbe5235
# Elastic Search 8526   2490b50ddd31a209774dc5e997ed1bf45e2bbdf0
# Elastic Search 8580   86bc79202d2b5db684ef07744da862fd1d884212
# Elastic Search 864    12e2ba822f52bcab5a74603f41233a6d5cb423f6
# Elastic Search 8893   0e5f9898d16e19607c11cca56172dd11f57bb67a
# Elastic Search 9317   00a1352d900cc803dfabc28cdafe465113d41837
#
#                      parents_author_date parents_is_merge parents_is_rebase  \
# Elastic Search 1134  2011-07-18 18:29:29            False             False
# Elastic Search 1154  2010-03-04 23:39:04            False             False
# Elastic Search 1162  2010-08-26 15:12:51            False             False
# Elastic Search 12193 2015-06-13 08:34:36            False             False
# Elastic Search 1380  2011-04-07 11:16:21            False             False
# Elastic Search 14782 2015-08-17 09:43:47            False              True
# Elastic Search 14782                 NaT             None              None
# Elastic Search 15858 2011-09-27 10:21:20            False             False
# Elastic Search 16246 2015-11-25 17:04:09            False             False
# Elastic Search 1626  2011-08-29 14:46:01            False             False
# Elastic Search 16790 2015-09-22 01:04:57             True             False
# Elastic Search 16790                 NaT             None              None
# Elastic Search 16790                 NaT             None              None
# Elastic Search 16790                 NaT             None              None
# Elastic Search 1725  2010-05-13 17:42:59            False             False
# Elastic Search 1814  2010-09-08 21:53:20            False             False
# Elastic Search 1948  2011-02-01 15:00:59            False             False
# Elastic Search 1960  2010-11-29 00:05:45            False             False
# Elastic Search 200   2010-03-31 19:46:21            False             False
# Elastic Search 2566  2010-09-21 13:07:51            False             False
# Elastic Search 2608  2010-11-27 21:30:18            False             False
# Elastic Search 2991  2013-01-30 10:20:41            False             False
# Elastic Search 3242  2012-09-20 16:10:56            False             False
# Elastic Search 3267  2011-07-11 01:10:16            False             False
# Elastic Search 3560  2013-07-30 14:44:30            False             False
# Elastic Search 4581  2012-11-26 08:02:54            False             False
# Elastic Search 4814  2014-01-17 14:33:13            False             False
# Elastic Search 5021  2013-12-18 14:08:23            False             False
# Elastic Search 5048  2013-12-18 16:44:43            False             False
# Elastic Search 5165  2013-08-16 01:15:25            False             False
# Elastic Search 5948  2014-01-10 22:30:05            False             False
# Elastic Search 7623  2010-03-12 14:28:37            False             False
# Elastic Search 764   2010-10-03 11:10:33            False             False
# Elastic Search 7686  2011-04-04 20:48:54            False             False
# Elastic Search 8125  2014-08-28 12:22:02            False             False
# Elastic Search 8438  2014-07-30 16:07:04            False             False
# Elastic Search 8507  2014-07-11 10:23:20            False              True
# Elastic Search 8526  2013-05-27 21:03:30            False             False
# Elastic Search 8580  2014-07-14 07:56:50            False             False
# Elastic Search 864   2010-03-02 20:16:35            False             False
# Elastic Search 8893  2014-07-10 15:11:21            False              True
# Elastic Search 9317  2014-11-05 16:45:35            False             False
#
#                       ...                    children_revision_hash  \
# Elastic Search 1134   ...  d905e6220970898c44b43d56f936e56b53fa3f4f
# Elastic Search 1154   ...  45489ed1af13c6090486c9357e8745c4929d4a83
# Elastic Search 1162   ...  e85c47db744334bf049a04656e7d8b19ac312af0
# Elastic Search 12193  ...  58ccb39deea9afb136d8ad9ce6defc7c67b52cad
# Elastic Search 1380   ...  7fcf82af807608a3e05a388ae16e713b55982cd0
# Elastic Search 14782  ...  c908c582c280a2f39b896797e683ea93b7ec902b
# Elastic Search 14782  ...                                      None
# Elastic Search 15858  ...  de8644d95a216c0251ca483f3c7fdcffc7d94547
# Elastic Search 16246  ...  9aa9447016755884836c33909ec720cb79324247
# Elastic Search 1626   ...  7420e99e7df6a33296850b5b25674ff06bf28959
# Elastic Search 16790  ...  de2566a0230d5dc9f31aabf16b510edc7c650b7a
# Elastic Search 16790  ...                                      None
# Elastic Search 16790  ...                                      None
# Elastic Search 16790  ...                                      None
# Elastic Search 1725   ...  f6a1a2fefba17851b458ee0ca6fba7e3691f891e
# Elastic Search 1814   ...  4e661c165a7590f8ffb5c01e00030b9daa1b8abc
# Elastic Search 1948   ...  eb1db1140ba7530bf7e95db55fbe423b0768431b
# Elastic Search 1960   ...  c0945831e86ddf17a573d381b9eb0b40c2e2196c
# Elastic Search 200    ...  aac05e262905c58306a21cdadfecb13f6cd774be
# Elastic Search 2566   ...  8cce3d6cce9983706a5ec3f4a8800addfd57cc86
# Elastic Search 2608   ...  a222de1dbf6518c3af5ce7ffc42f06d0c47479b1
# Elastic Search 2991   ...  5c40c97e6e8c697e36a2742c844ccf1cc45cee9d
# Elastic Search 3242   ...  a3af3d2f47590c859cac1dbc9f6fa273fc6bbd22
# Elastic Search 3267   ...  c04be9d36543f1a68ba4ba0c9385c6c73500930d
# Elastic Search 3560   ...  daf7e04caf68f1c005600d29a71b75ef384e1651
# Elastic Search 4581   ...  dfebf610f2fab83c56b3df10a2f2de668b58fd24
# Elastic Search 4814   ...  13e6f1933bb89234b622409671d0581fd5d14a70
# Elastic Search 5021   ...  52db8eb324a829e0511f2f946d3994a34bf39c5b
# Elastic Search 5048   ...  9fdbbecbedb56889f4c6e4de92ee5e5a39cb4a15
# Elastic Search 5165   ...  ac06722e32d7a92d029ffaabe8b0e0e2436ae5cb
# Elastic Search 5948   ...  5e102f53eec60041d35f81e3329e24b4ba734383
# Elastic Search 7623   ...  6fe329ab697a9640648ea6ad84fb24b5282eb5c2
# Elastic Search 764    ...  6371ed7d784df198b7772b009a72ea4bc9218d5d
# Elastic Search 7686   ...  79939222e465543f128fd6b1d46c06eefee7c1ef
# Elastic Search 8125   ...  91b8498cec8046cb540d0b2787cbe5dfedcf08d5
# Elastic Search 8438   ...  d613f5f09715938bad8479c8db28ad5fdcab5273
# Elastic Search 8507   ...  3c4caea843cde549fe5320b79bc51ec368224bbf
# Elastic Search 8526   ...  48c9e0c4987ccff20ba9a940a4516f69718d5974
# Elastic Search 8580   ...  74927adced765ca1eddce784efcda4ea1f9b127b
# Elastic Search 864    ...  e276928ebf151d5e6f684edac1d25483671c151d
# Elastic Search 8893   ...  75ed24f6b6a96ac268f7b085550020252d94d908
# Elastic Search 9317   ...  d5d8ec886a4254637731a14d16676f15202c4597
#
#                      children_author_date children_is_merge  \
# Elastic Search 1134   2011-07-18 19:56:28             False
# Elastic Search 1154   2010-03-04 23:50:40             False
# Elastic Search 1162   2010-08-27 10:52:58             False
# Elastic Search 12193  2015-06-13 18:29:18             False
# Elastic Search 1380   2011-04-07 11:44:34             False
# Elastic Search 14782  2015-08-17 14:14:20              True
# Elastic Search 14782                  NaT              None
# Elastic Search 15858  2011-09-27 18:45:10             False
# Elastic Search 16246  2015-11-25 19:31:17             False
# Elastic Search 1626   2011-08-28 21:34:38             False
# Elastic Search 16790  2015-09-22 05:10:58              True
# Elastic Search 16790                  NaT              None
# Elastic Search 16790                  NaT              None
# Elastic Search 16790                  NaT              None
# Elastic Search 1725   2010-05-13 18:26:42             False
# Elastic Search 1814   2010-09-10 13:04:10             False
# Elastic Search 1948   2011-02-01 21:08:52             False
# Elastic Search 1960   2010-11-29 11:59:30             False
# Elastic Search 200    2010-03-31 21:35:54             False
# Elastic Search 2566   2010-09-21 15:41:19             False
# Elastic Search 2608   2010-11-28 12:57:17             False
# Elastic Search 2991   2013-01-30 13:42:07             False
# Elastic Search 3242   2012-09-21 16:57:21             False
# Elastic Search 3267   2011-07-11 21:34:11             False
# Elastic Search 3560   2013-07-30 15:16:35             False
# Elastic Search 4581   2012-12-05 23:23:17             False
# Elastic Search 4814   2014-01-17 14:37:18             False
# Elastic Search 5021   2013-12-18 15:05:35             False
# Elastic Search 5048   2013-12-18 18:05:47             False
# Elastic Search 5165   2013-08-09 10:53:43             False
# Elastic Search 5948   2014-01-15 18:52:23             False
# Elastic Search 7623   2010-03-12 14:36:31             False
# Elastic Search 764    2010-10-03 13:52:44             False
# Elastic Search 7686   2011-04-04 21:42:46             False
# Elastic Search 8125   2014-08-29 06:46:03             False
# Elastic Search 8438   2014-07-30 17:21:36             False
# Elastic Search 8507   2014-07-29 02:01:13             False
# Elastic Search 8526   2013-05-27 21:35:57             False
# Elastic Search 8580   2014-05-14 15:39:07             False
# Elastic Search 864    2010-03-02 23:49:25             False
# Elastic Search 8893   2014-07-10 16:02:47             False
# Elastic Search 9317   2014-11-07 09:29:06             False
#
#                      children_is_rebase children_is_review_commit  \
# Elastic Search 1134               False                       0.0
# Elastic Search 1154               False                       0.0
# Elastic Search 1162               False                       0.0
# Elastic Search 12193              False                       0.0
# Elastic Search 1380               False                       0.0
# Elastic Search 14782              False                       0.0
# Elastic Search 14782               None                       NaN
# Elastic Search 15858              False                       1.0
# Elastic Search 16246              False                       2.0
# Elastic Search 1626               False                       0.0
# Elastic Search 16790              False                       0.0
# Elastic Search 16790               None                       NaN
# Elastic Search 16790               None                       NaN
# Elastic Search 16790               None                       NaN
# Elastic Search 1725               False                       0.0
# Elastic Search 1814               False                       0.0
# Elastic Search 1948               False                       1.0
# Elastic Search 1960               False                       0.0
# Elastic Search 200                False                       0.0
# Elastic Search 2566               False                       0.0
# Elastic Search 2608               False                       0.0
# Elastic Search 2991               False                       0.0
# Elastic Search 3242               False                       1.0
# Elastic Search 3267               False                       0.0
# Elastic Search 3560               False                       0.0
# Elastic Search 4581               False                       0.0
# Elastic Search 4814               False                       0.0
# Elastic Search 5021               False                       0.0
# Elastic Search 5048               False                       0.0
# Elastic Search 5165                True                       0.0
# Elastic Search 5948               False                       0.0
# Elastic Search 7623               False                       0.0
# Elastic Search 764                False                       0.0
# Elastic Search 7686               False                       0.0
# Elastic Search 8125               False                       0.0
# Elastic Search 8438               False                       0.0
# Elastic Search 8507               False                       0.0
# Elastic Search 8526               False                       0.0
# Elastic Search 8580                True                       1.0
# Elastic Search 864                False                       0.0
# Elastic Search 8893               False                       1.0
# Elastic Search 9317               False                       0.0
#
#                                 children_parents_revision_hash  \
# Elastic Search 1134   10660d390d760cde78fb115107c04e1cf104a4da
# Elastic Search 1154   7a38e384c9ff783f17e9db92a730bdf654dbda6b
# Elastic Search 1162   e5b041c8efd408fdc71fd2f2c84439e5a4985244
# Elastic Search 12193  e88535a67e9594f3135465b5021ba9b502fef950
# Elastic Search 1380   16a046f686c26309ee0041df8987a4d2ffedd956
# Elastic Search 14782  a75adaaaaaa632c036464da8fa24770796f77852
# Elastic Search 14782  a9b2b033e3eb8badbd6ffed04722d299dbfcbf6f
# Elastic Search 15858  4088236cf75b793c7a2a80f5f7be5b326b607378
# Elastic Search 16246  7caee2fa4d918d4c6978bcf986a158d03bf7db2a
# Elastic Search 1626   1f30681a84fcafe9cf6e6b8a2801ea1791b9edc0
# Elastic Search 16790  093791e82dfe7c3e16ddb1f199fede2cf86b6797
# Elastic Search 16790  b582de79ae1b669e76d0ffb70e90075bd9d0cddf
# Elastic Search 16790                                      None
# Elastic Search 16790                                      None
# Elastic Search 1725   3d310406b71973e82f94f60b8dab0c90729a579a
# Elastic Search 1814   b31b0e979c616251ed75b18a87193bd76b75eff3
# Elastic Search 1948   8587f1611912c6633b72909939e91d226575dd90
# Elastic Search 1960   103221e58a85dc5d133cc70af898102735c4375f
# Elastic Search 200    2ea7423f3ac68578a81d92f50b6484cf1db2203d
# Elastic Search 2566   aa68667d636d61b0cc67810e1e2489d1246e9af6
# Elastic Search 2608   8285ffe22175bf4592e79bb881a6451741ccdac8
# Elastic Search 2991   bc20f068c9c62b69260f3b24adaaf9fb3ff3d371
# Elastic Search 3242   4f5e62e9882b36271280ad4e47e61aba2d7669f1
# Elastic Search 3267   567cf6b5c3bbc4486b0472c8abe588ab6215637c
# Elastic Search 3560   a235a5594338789a448742fce19549206dd5b30c
# Elastic Search 4581   22722840d4331a83fcfdd8edea22d372feba16ab
# Elastic Search 4814   3f1472505723866794d875c00bde575d988e120d
# Elastic Search 5021   07443089ce761cdfcf9206ad179381db7249d01a
# Elastic Search 5048   e7e1667a26de5472e3419c586682b92c37c6e7d3
# Elastic Search 5165   459d59a04ad4eb1671bac50a6faf3a7ad372d0e4
# Elastic Search 5948   8561f897a984807958a543e378ab01349935a739
# Elastic Search 7623   ef85412f98e97ff5471013eab59fd8cb3046c17a
# Elastic Search 764    7180636df6dfe6b18bf738ee2285549ea95a8cb9
# Elastic Search 7686   90a339ad5e4a61e750d0342be6326de46f45bedc
# Elastic Search 8125   c55341bf515fec6d4135cee8a6e9a7a9764da17f
# Elastic Search 8438   976448e3395609276446e2b8dbeddb046823aa2e
# Elastic Search 8507   91c4824a0f768f2d3e3651958656384d0735a85e
# Elastic Search 8526   fc51ebfce8a87252d868d1f160ae740972b8e48a
# Elastic Search 8580   8865e60e936b57feb1a31d23b29ba0b212492766
# Elastic Search 864    03ee0a942df39c01e5e4f4ecb392a746e3d979af
# Elastic Search 8893   4f131dfffbdadf5c5f9c9b7a03f9660233e04f72
# Elastic Search 9317   bb49554c33b310e0e615c12befe8846a7d27c951
#
#                      children_parents_author_date children_parents_is_merge  \
# Elastic Search 1134           2011-07-18 19:15:22                     False
# Elastic Search 1154           2010-03-04 23:48:56                     False
# Elastic Search 1162           2010-08-26 21:41:55                     False
# Elastic Search 12193          2015-06-13 09:28:05                     False
# Elastic Search 1380           2011-04-07 11:30:12                     False
# Elastic Search 14782          2015-08-17 13:52:36                     False
# Elastic Search 14782          2015-08-15 15:53:43                     False
# Elastic Search 15858          2011-09-27 10:47:59                     False
# Elastic Search 16246          2015-11-25 17:54:48                     False
# Elastic Search 1626           2011-08-27 14:40:00                     False
# Elastic Search 16790          2015-09-22 04:57:51                     False
# Elastic Search 16790          2015-09-22 04:46:31                      True
# Elastic Search 16790                          NaT                      None
# Elastic Search 16790                          NaT                      None
# Elastic Search 1725           2010-05-13 18:07:30                     False
# Elastic Search 1814           2010-09-09 12:47:55                     False
# Elastic Search 1948           2011-02-01 20:16:09                     False
# Elastic Search 1960           2010-11-29 00:55:23                     False
# Elastic Search 200            2010-03-31 21:20:45                     False
# Elastic Search 2566           2010-09-21 15:32:34                     False
# Elastic Search 2608           2010-11-28 00:23:38                     False
# Elastic Search 2991           2013-01-30 10:49:20                     False
# Elastic Search 3242           2012-09-21 11:36:19                     False
# Elastic Search 3267           2011-07-11 18:49:33                     False
# Elastic Search 3560           2013-07-30 15:06:55                     False
# Elastic Search 4581           2012-11-26 08:04:26                     False
# Elastic Search 4814           2014-01-17 14:13:51                     False
# Elastic Search 5021           2013-12-18 14:44:57                     False
# Elastic Search 5048           2013-12-18 15:39:15                     False
# Elastic Search 5165           2013-08-16 08:57:17                     False
# Elastic Search 5948           2014-01-15 17:22:36                     False
# Elastic Search 7623           2010-03-12 14:30:30                     False
# Elastic Search 764            2010-10-03 12:31:36                     False
# Elastic Search 7686           2011-04-04 21:17:07                     False
# Elastic Search 8125           2014-08-28 18:58:34                     False
# Elastic Search 8438           2014-07-30 17:06:52                     False
# Elastic Search 8507           2014-07-14 11:22:58                     False
# Elastic Search 8526           2013-05-27 21:25:24                     False
# Elastic Search 8580           2014-07-14 08:42:15                     False
# Elastic Search 864            2010-03-02 22:50:53                     False
# Elastic Search 8893           2014-07-10 16:01:03                     False
# Elastic Search 9317           2014-11-05 22:12:54                     False
#
#                      children_parents_is_rebase  \
# Elastic Search 1134                       False
# Elastic Search 1154                       False
# Elastic Search 1162                       False
# Elastic Search 12193                      False
# Elastic Search 1380                       False
# Elastic Search 14782                      False
# Elastic Search 14782                      False
# Elastic Search 15858                      False
# Elastic Search 16246                      False
# Elastic Search 1626                        True
# Elastic Search 16790                      False
# Elastic Search 16790                      False
# Elastic Search 16790                       None
# Elastic Search 16790                       None
# Elastic Search 1725                       False
# Elastic Search 1814                       False
# Elastic Search 1948                       False
# Elastic Search 1960                       False
# Elastic Search 200                        False
# Elastic Search 2566                       False
# Elastic Search 2608                       False
# Elastic Search 2991                       False
# Elastic Search 3242                       False
# Elastic Search 3267                       False
# Elastic Search 3560                       False
# Elastic Search 4581                       False
# Elastic Search 4814                        True
# Elastic Search 5021                       False
# Elastic Search 5048                        True
# Elastic Search 5165                       False
# Elastic Search 5948                       False
# Elastic Search 7623                       False
# Elastic Search 764                        False
# Elastic Search 7686                       False
# Elastic Search 8125                       False
# Elastic Search 8438                       False
# Elastic Search 8507                       False
# Elastic Search 8526                       False
# Elastic Search 8580                       False
# Elastic Search 864                        False
# Elastic Search 8893                       False
# Elastic Search 9317                       False
#
#                      children_parents_is_review_commit
# Elastic Search 1134                                0.0
# Elastic Search 1154                                0.0
# Elastic Search 1162                                0.0
# Elastic Search 12193                               0.0
# Elastic Search 1380                                0.0
# Elastic Search 14782                               0.0
# Elastic Search 14782                               1.0
# Elastic Search 15858                               1.0
# Elastic Search 16246                               2.0
# Elastic Search 1626                                0.0
# Elastic Search 16790                               1.0
# Elastic Search 16790                               0.0
# Elastic Search 16790                               NaN
# Elastic Search 16790                               NaN
# Elastic Search 1725                                0.0
# Elastic Search 1814                                0.0
# Elastic Search 1948                                1.0
# Elastic Search 1960                                0.0
# Elastic Search 200                                 0.0
# Elastic Search 2566                                0.0
# Elastic Search 2608                                0.0
# Elastic Search 2991                                0.0
# Elastic Search 3242                                1.0
# Elastic Search 3267                                0.0
# Elastic Search 3560                                0.0
# Elastic Search 4581                                0.0
# Elastic Search 4814                                0.0
# Elastic Search 5021                                0.0
# Elastic Search 5048                                0.0
# Elastic Search 5165                                0.0
# Elastic Search 5948                                0.0
# Elastic Search 7623                                0.0
# Elastic Search 764                                 0.0
# Elastic Search 7686                                0.0
# Elastic Search 8125                                0.0
# Elastic Search 8438                                0.0
# Elastic Search 8507                                0.0
# Elastic Search 8526                                0.0
# Elastic Search 8580                                1.0
# Elastic Search 864                                 0.0
# Elastic Search 8893                                1.0
# Elastic Search 9317                                0.0
#
# [42 rows x 26 columns]

# %%
result.to_csv(f'{project}_family.csv')
